# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matlplotlib inline
# Out:
# UsageError: Line magic function `%matlplotlib` not found.

# %%
df = pd.read_csv('Subcription App Behaviour.csv')

# %%
df
# Out:
#          user first_open  dayofweek       hour  age  \
# 0      235136    14:51.3          3   02:00:00   23
# 1      333588    16:00.9          6   01:00:00   24
# 2      254414    19:09.2          1   19:00:00   23
# 3      234192    08:46.4          4   16:00:00   28
# 4       51549    50:48.7          1   18:00:00   31
# ...       ...        ...        ...        ...  ...
# 49995  222774    46:17.9          3   13:00:00   32
# 49996  169179    05:17.8          1   00:00:00   35
# 49997  302367    41:51.2          2   22:00:00   39
# 49998  324905    33:04.3          6   12:00:00   27
# 49999   27047    22:44.6          4   01:00:00   25
#
#                                              screen_list  numscreens  \
# 0      idscreen,joinscreen,Cycle,product_review,ScanP...          15
# 1      joinscreen,product_review,product_review2,Scan...          13
# 2                                      Splash,Cycle,Loan           3
# ...

# %%
df.describe()
# Out:
#                 user     dayofweek          age    numscreens      minigame  \
# count   50000.000000  50000.000000  50000.00000  50000.000000  50000.000000
# mean   186889.729900      3.029860     31.72436     21.095900      0.107820
# std    107768.520361      2.031997     10.80331     15.728812      0.310156
# min        13.000000      0.000000     16.00000      1.000000      0.000000
# 25%     93526.750000      1.000000     24.00000     10.000000      0.000000
# 50%    187193.500000      3.000000     29.00000     18.000000      0.000000
# 75%    279984.250000      5.000000     37.00000     28.000000      0.000000
# max    373662.000000      6.000000    101.00000    325.000000      1.000000
#
#        used_premium_feature      enrolled         liked
# count          50000.000000  50000.000000  50000.000000
# mean               0.172020      0.621480      0.165000
# std                0.377402      0.485023      0.371184
# min                0.000000      0.000000      0.000000
# ...

# %%
df.head()
# Out:
#      user first_open  dayofweek       hour  age  \
# 0  235136    14:51.3          3   02:00:00   23
# 1  333588    16:00.9          6   01:00:00   24
# 2  254414    19:09.2          1   19:00:00   23
# 3  234192    08:46.4          4   16:00:00   28
# 4   51549    50:48.7          1   18:00:00   31
#
#                                          screen_list  numscreens  minigame  \
# 0  idscreen,joinscreen,Cycle,product_review,ScanP...          15         0
# 1  joinscreen,product_review,product_review2,Scan...          13         0
# 2                                  Splash,Cycle,Loan           3         0
# 3  product_review,Home,product_review,Loan3,Finan...          40         0
# 4  idscreen,joinscreen,Cycle,Credit3Container,Sca...          32         0
#
#    used_premium_feature  enrolled enrolled_date  liked
# 0                     0         0           NaN      0
# 1                     0         0           NaN      0
# 2                     1         0           NaN      1
# ...

# %%
df.tail()
# Out:
#          user first_open  dayofweek       hour  age  \
# 49995  222774    46:17.9          3   13:00:00   32
# 49996  169179    05:17.8          1   00:00:00   35
# 49997  302367    41:51.2          2   22:00:00   39
# 49998  324905    33:04.3          6   12:00:00   27
# 49999   27047    22:44.6          4   01:00:00   25
#
#                                              screen_list  numscreens  \
# 49995  Splash,Home,ScanPreview,VerifyPhone,VerifySSN,...          13
# 49996                 Cycle,Splash,Home,RewardsContainer           4
# 49997  joinscreen,product_review,product_review2,Scan...          25
# 49998  Cycle,Home,product_review,product_review,produ...          26
# 49999  product_review,ScanPreview,VerifyDateOfBirth,V...          26
#
#        minigame  used_premium_feature  enrolled enrolled_date  liked
# 49995         0                     0         1       47:52.9      0
# 49996         0                     1         0           NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
# user                    50000 non-null int64
# first_open              50000 non-null object
# dayofweek               50000 non-null int64
# hour                    50000 non-null object
# age                     50000 non-null int64
# screen_list             50000 non-null object
# numscreens              50000 non-null int64
# minigame                50000 non-null int64
# used_premium_feature    50000 non-null int64
# enrolled                50000 non-null int64
# enrolled_date           31074 non-null object
# liked                   50000 non-null int64
# dtypes: int64(8), object(4)
# memory usage: 4.6+ MB

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(),cbar=False, yticklabels=False,cmap='plasma')

# %%
df['used_premium_feature']
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 49995    0
# 49996    1
# 49997    0
# 49998    0
# 49999    0
# Name: used_premium_feature, Length: 50000, dtype: int64

# %%
sns.countplot(x='used_premium_feature', data =df)

# %%
sns.countplot(x='liked', data =df)

# %%
df['age'].hist(bins=100)

# %%
sns.countplot(x='used_premium_feature', hue='age', data=df)

# %%
sns.countplot(x='liked', hue='age', data=df)

# %%
sns.catplot(x='age',y='used_premium_feature',data =df,height=6,kind='bar')

# %%
df
# Out:
#          user first_open  dayofweek       hour  age  \
# 0      235136    14:51.3          3   02:00:00   23
# 1      333588    16:00.9          6   01:00:00   24
# 2      254414    19:09.2          1   19:00:00   23
# 3      234192    08:46.4          4   16:00:00   28
# 4       51549    50:48.7          1   18:00:00   31
# ...       ...        ...        ...        ...  ...
# 49995  222774    46:17.9          3   13:00:00   32
# 49996  169179    05:17.8          1   00:00:00   35
# 49997  302367    41:51.2          2   22:00:00   39
# 49998  324905    33:04.3          6   12:00:00   27
# 49999   27047    22:44.6          4   01:00:00   25
#
#                                              screen_list  numscreens  \
# 0      idscreen,joinscreen,Cycle,product_review,ScanP...          15
# 1      joinscreen,product_review,product_review2,Scan...          13
# 2                                      Splash,Cycle,Loan           3
# ...

# %%
df.drop(columns='screen_list',inplace=True)

# %%
df
# Out:
#          user first_open  dayofweek       hour  age  numscreens  minigame  \
# 0      235136    14:51.3          3   02:00:00   23          15         0
# 1      333588    16:00.9          6   01:00:00   24          13         0
# 2      254414    19:09.2          1   19:00:00   23           3         0
# 3      234192    08:46.4          4   16:00:00   28          40         0
# 4       51549    50:48.7          1   18:00:00   31          32         0
# ...       ...        ...        ...        ...  ...         ...       ...
# 49995  222774    46:17.9          3   13:00:00   32          13         0
# 49996  169179    05:17.8          1   00:00:00   35           4         0
# 49997  302367    41:51.2          2   22:00:00   39          25         0
# 49998  324905    33:04.3          6   12:00:00   27          26         0
# 49999   27047    22:44.6          4   01:00:00   25          26         0
#
#        used_premium_feature  enrolled enrolled_date  liked
# ...

# %%
df.drop(columns=['user','first_open','enrolled_date'],inplace=True)

# %%
df
# Out:
#        dayofweek       hour  age  numscreens  minigame  used_premium_feature  \
# 0              3   02:00:00   23          15         0                     0
# 1              6   01:00:00   24          13         0                     0
# 2              1   19:00:00   23           3         0                     1
# 3              4   16:00:00   28          40         0                     0
# 4              1   18:00:00   31          32         0                     0
# ...          ...        ...  ...         ...       ...                   ...
# 49995          3   13:00:00   32          13         0                     0
# 49996          1   00:00:00   35           4         0                     1
# 49997          2   22:00:00   39          25         0                     0
# 49998          6   12:00:00   27          26         0                     0
# 49999          4   01:00:00   25          26         0                     0
#
#        enrolled  liked
# ...

# %%
sns.distplot(df['age'],bins=100)

# %%
ar = df['hour']

# %%
ar
# Out:
# 0         02:00:00
# 1         01:00:00
# 2         19:00:00
# 3         16:00:00
# 4         18:00:00
#            ...
# 49995     13:00:00
# 49996     00:00:00
# 49997     22:00:00
# 49998     12:00:00
# 49999     01:00:00
# Name: hour, Length: 50000, dtype: object

# %%
import datetime

# %%
for i in range(0,50000):
        (h,m,s) = ar[i].split(':')
        ar[i] = int(h) * 3600 + int(m) * 60 + int(s)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ar
# Out:
# 0         7200
# 1         3600
# 2        68400
# 3        57600
# 4        64800
#          ...
# 49995    46800
# 49996        0
# 49997    79200
# 49998    43200
# 49999     3600
# Name: hour, Length: 50000, dtype: object

# %%
seconds = np.array([ar])

# %%
seconds
# Out:
# array([[7200, 3600, 68400, ..., 79200, 43200, 3600]], dtype=object)

# %%
df = pd.concat([df,ar],axis=1)

# %%
df
# Out:
#        dayofweek   hour  age  numscreens  minigame  used_premium_feature  \
# 0              3   7200   23          15         0                     0
# 1              6   3600   24          13         0                     0
# 2              1  68400   23           3         0                     1
# 3              4  57600   28          40         0                     0
# 4              1  64800   31          32         0                     0
# ...          ...    ...  ...         ...       ...                   ...
# 49995          3  46800   32          13         0                     0
# 49996          1      0   35           4         0                     1
# 49997          2  79200   39          25         0                     0
# 49998          6  43200   27          26         0                     0
# 49999          4   3600   25          26         0                     0
#
#        enrolled  liked   hour
# 0             0      0   7200
# ...

# %%
updated_time = ar/3600

# %%
updated_time
# Out:
# 0         2
# 1         1
# 2        19
# 3        16
# 4        18
#          ..
# 49995    13
# 49996     0
# 49997    22
# 49998    12
# 49999     1
# Name: hour, Length: 50000, dtype: object

# %%
time
# Out:
#       hour hour         hour         hour
# 0        2    2  0.000555556  0.000555556
# 1        1    1  0.000277778  0.000277778
# 2       19   19   0.00527778   0.00527778
# 3       16   16   0.00444444   0.00444444
# 4       18   18        0.005        0.005
# ...    ...  ...          ...          ...
# 49995   13   13   0.00361111   0.00361111
# 49996    0    0            0            0
# 49997   22   22   0.00611111   0.00611111
# 49998   12   12   0.00333333   0.00333333
# 49999    1    1  0.000277778  0.000277778
#
# [50000 rows x 4 columns]

# %%
df.drop('hour',axis=1,inplace=True)

# %%
df
# Out:
#        dayofweek  age  numscreens  minigame  used_premium_feature  enrolled  \
# 0              3   23          15         0                     0         0
# 1              6   24          13         0                     0         0
# 2              1   23           3         0                     1         0
# 3              4   28          40         0                     0         1
# 4              1   31          32         0                     0         1
# ...          ...  ...         ...       ...                   ...       ...
# 49995          3   32          13         0                     0         1
# 49996          1   35           4         0                     1         0
# 49997          2   39          25         0                     0         0
# 49998          6   27          26         0                     0         1
# 49999          4   25          26         0                     0         0
#
#        liked
# 0          0
# 1          0
# ...

# %%
df = pd.concat([df,updated_time],axis =1)

# %%
df
# Out:
#        dayofweek  age  numscreens  minigame  used_premium_feature  enrolled  \
# 0              3   23          15         0                     0         0
# 1              6   24          13         0                     0         0
# 2              1   23           3         0                     1         0
# 3              4   28          40         0                     0         1
# 4              1   31          32         0                     0         1
# ...          ...  ...         ...       ...                   ...       ...
# 49995          3   32          13         0                     0         1
# 49996          1   35           4         0                     1         0
# 49997          2   39          25         0                     0         0
# 49998          6   27          26         0                     0         1
# 49999          4   25          26         0                     0         0
#
#        liked hour
# 0          0    2
# ...

# %%
X = df
y = df['enrolled']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 1/3,random_state = 0)

# %%
X_train
# Out:
#        dayofweek  age  numscreens  minigame  used_premium_feature  enrolled  \
# 44951          2   45          36         0                     0         1
# 26174          5   26          21         0                     0         1
# 43272          1   29          12         1                     0         1
# 5721           2   24          33         0                     0         1
# 48450          4   36          18         0                     0         1
# ...          ...  ...         ...       ...                   ...       ...
# 21243          5   19           6         0                     0         0
# 45891          0   22           4         1                     1         0
# 42613          3   25          43         0                     0         0
# 43567          4   27           4         1                     0         1
# 2732           1   20          13         0                     0         1
#
#        liked hour
# 44951      0   22
# ...

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, predictions)
print(cm)
accuracy_score(y_test, predictions)
# Out:
# [[ 5798   494]
#  [   99 10276]]
# 0.9644207115857683
